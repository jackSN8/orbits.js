# %% [markdown]
# $$(\ddot{r} - r\dot{\phi}^2)\,\hat{\bm{r}} + (r\ddot{\phi} + 2\dot{r}\dot{\phi})\,\hat{\bm{\phi}}=g\hat{r}-\frac{\tau}{m|\dot{r}|}[\dot{r}\hat{r}-r\hat{\phi}\dot{\phi}]$$
# $$\dot{m}=\frac{\Tau}{V_e}$$

# %% [markdown]
# Idea is that the only truely important free paremeter is phi initial. We land at $\phi = 0$, initial angular velocity is just orbital velocity (perhaps reduced by 100m/s simulating a de-orbit burn) converted to rad/s. We can then integrate the trajectory forward, compute the error and work towards a converged solution.

# %%
#body params

r_moon = 1e6
g_moon = 1

phif=0
rf=r_moon
dtrf=0
dtphif=0
m0=1e4
thrust=1e5

v_init=1e3

def eq_motion(t,r,phi,dr,dphi):
    acc = g_moon*
